# %% [markdown]
# # Artificial Intelligence Nanodegree
#
# ## Convolutional Neural Networks
#
# ---
#
# In this notebook, we use transfer learning to train a CNN to classify dog breeds.
#
# ### 1. Load Dog Dataset
#
# Before running the code cell below, download the dataset of dog images [here](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/dogImages.zip) and place it in the respository.

# %%
from sklearn.datasets import load_files       
from keras.utils import np_utils
import numpy as np
from glob import glob

# define function to load train, test, and validation datasets
def load_dataset(path):
    data = load_files(path)
    dog_files = np.array(data['filenames'])
    dog_targets = np_utils.to_categorical(np.array(data['target']), 133)
    return dog_files, dog_targets

# load train, test, and validation datasets
train_files, train_targets = load_dataset('dogImages/train')
valid_files, valid_targets = load_dataset('dogImages/valid')
test_files, test_targets = load_dataset('dogImages/test')

# load ordered list of dog names
dog_names = [item[25:-1] for item in glob('dogImages/train/*/')]

# print statistics about the dataset
print('There are %d total dog categories.' % len(dog_names))
print('There are %s total dog images.\n' % str(len(train_files) + len(valid_files) + len(test_files)))
print('There are %d training dog images.' % len(train_files))
print('There are %d validation dog images.' % len(valid_files))
print('There are %d test dog images.'% len(test_files))
# Out:
# Using TensorFlow backend.
# There are 133 total dog categories.
# There are 8351 total dog images.
#
# There are 6680 training dog images.
# There are 835 validation dog images.
# There are 836 test dog images.

# %% [markdown]
# ### 2. Visualize the First 12 Training Images

# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

def visualize_img(img_path, ax):
    img = cv2.imread(img_path)
    ax.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    
fig = plt.figure(figsize=(20, 10))
for i in range(12):
    ax = fig.add_subplot(3, 4, i + 1, xticks=[], yticks=[])
    visualize_img(train_files[i], ax)

# %% [markdown]
# ### 3. Obtain the VGG-16 Bottleneck Features
#
# Before running the code cell below, download the file linked [here](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogVGG16Data.npz) and place it in the `bottleneck_features/` folder.

# %%
bottleneck_features = np.load('bottleneck_features/DogVGG16Data.npz')
train_vgg16 = bottleneck_features['train']
valid_vgg16 = bottleneck_features['valid']
test_vgg16 = bottleneck_features['test']

# %% [markdown]
# ### 4. Define a Model Architecture (Model 1)

# %%
from keras.layers import Dense, Flatten
from keras.models import Sequential

model = Sequential()
model.add(Flatten(input_shape=(7, 7, 512)))
model.add(Dense(133, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='rmsprop', 
                  metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_1 (Flatten)          (None, 25088)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 133)               3336837
# =================================================================
# Total params: 3,336,837
# Trainable params: 3,336,837
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 5. Define another Model Architecture (Model 2)

# %%
from keras.layers import GlobalAveragePooling2D

model = Sequential()
model.add(GlobalAveragePooling2D(input_shape=(7, 7, 512)))
model.add(Dense(133, activation='softmax'))
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# global_average_pooling2d_1 ( (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 133)               68229
# =================================================================
# Total params: 68,229
# Trainable params: 68,229
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 6. Compile the Model (Model 2)

# %%
# model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])
model.compile(loss='categorical_crossentropy', optimizer='sgd', metrics=['accuracy'])

# %% [markdown]
# ### 7. Train the Model (Model 2)

# %%
from keras.callbacks import ModelCheckpoint   

# train the model
checkpointer = ModelCheckpoint(filepath='dogvgg16.weights.best.hdf5', verbose=1, 
                               save_best_only=True)
model.fit(train_vgg16, train_targets, epochs=50, validation_data=(valid_vgg16, valid_targets), 
          callbacks=[checkpointer], verbose=1, shuffle=True)
# Out:
# Train on 6680 samples, validate on 835 samples
# Epoch 1/50
# 6680/6680 [==============================] - 6s 844us/step - loss: 0.0328 - accuracy: 0.9928 - val_loss: 1.7515 - val_accuracy: 0.7305
#
# Epoch 00001: val_loss improved from inf to 1.75149, saving model to dogvgg16.weights.best.hdf5
# Epoch 2/50
# 6680/6680 [==============================] - 2s 258us/step - loss: 0.0163 - accuracy: 0.9964 - val_loss: 1.6971 - val_accuracy: 0.7377
#
# Epoch 00002: val_loss improved from 1.75149 to 1.69706, saving model to dogvgg16.weights.best.hdf5
# Epoch 3/50
# 6680/6680 [==============================] - 2s 248us/step - loss: 0.0138 - accuracy: 0.9975 - val_loss: 1.6682 - val_accuracy: 0.7353
#
# Epoch 00003: val_loss improved from 1.69706 to 1.66816, saving model to dogvgg16.weights.best.hdf5
# Epoch 4/50
# 6680/6680 [==============================] - 2s 250us/step - loss: 0.0157 - accuracy: 0.9958 - val_loss: 1.6644 - val_accuracy: 0.7401
#
# Epoch 00004: val_loss improved from 1.66816 to 1.66436, saving model to dogvgg16.weights.best.hdf5
# Epoch 5/50
# 6680/6680 [==============================] - 2s 245us/step - loss: 0.0147 - accuracy: 0.9973 - val_loss: 1.6725 - val_accuracy: 0.7401
#
# Epoch 00005: val_loss did not improve from 1.66436
# Epoch 6/50
# 6680/6680 [==============================] - 2s 249us/step - loss: 0.0204 - accuracy: 0.9949 - val_loss: 1.6874 - val_accuracy: 0.7341
#
# Epoch 00006: val_loss did not improve from 1.66436
# Epoch 7/50
# 6680/6680 [==============================] - 2s 251us/step - loss: 0.0105 - accuracy: 0.9973 - val_loss: 1.7292 - val_accuracy: 0.7341
#
# Epoch 00007: val_loss did not improve from 1.66436
# Epoch 8/50
# 6680/6680 [==============================] - 2s 253us/step - loss: 0.0098 - accuracy: 0.9978 - val_loss: 1.6796 - val_accuracy: 0.7377
#
# Epoch 00008: val_loss did not improve from 1.66436
# Epoch 9/50
# 6680/6680 [==============================] - 2s 243us/step - loss: 0.0160 - accuracy: 0.9973 - val_loss: 1.6686 - val_accuracy: 0.7365
#
# Epoch 00009: val_loss did not improve from 1.66436
# Epoch 10/50
# 6680/6680 [==============================] - 2s 253us/step - loss: 0.0188 - accuracy: 0.9967 - val_loss: 1.7081 - val_accuracy: 0.7353
#
# Epoch 00010: val_loss did not improve from 1.66436
# Epoch 11/50
# 6680/6680 [==============================] - 2s 250us/step - loss: 0.0116 - accuracy: 0.9973 - val_loss: 1.6775 - val_accuracy: 0.7377
#
# Epoch 00011: val_loss did not improve from 1.66436
# Epoch 12/50
# 6680/6680 [==============================] - 2s 248us/step - loss: 0.0113 - accuracy: 0.9978 - val_loss: 1.6954 - val_accuracy: 0.7401
#
# Epoch 00012: val_loss did not improve from 1.66436
# Epoch 13/50
# 6680/6680 [==============================] - 2s 253us/step - loss: 0.0142 - accuracy: 0.9975 - val_loss: 1.6725 - val_accuracy: 0.7365
#
# Epoch 00013: val_loss did not improve from 1.66436
# Epoch 14/50
# 6680/6680 [==============================] - 2s 244us/step - loss: 0.0106 - accuracy: 0.9978 - val_loss: 1.6870 - val_accuracy: 0.7329
#
# Epoch 00014: val_loss did not improve from 1.66436
# Epoch 15/50
# 6680/6680 [==============================] - 2s 241us/step - loss: 0.0065 - accuracy: 0.9987 - val_loss: 1.6536 - val_accuracy: 0.7377
#
# Epoch 00015: val_loss improved from 1.66436 to 1.65356, saving model to dogvgg16.weights.best.hdf5
# Epoch 16/50
# 6680/6680 [==============================] - 2s 247us/step - loss: 0.0139 - accuracy: 0.9975 - val_loss: 1.7166 - val_accuracy: 0.7317
#
# Epoch 00016: val_loss did not improve from 1.65356
# Epoch 17/50
# 6680/6680 [==============================] - 2s 245us/step - loss: 0.0148 - accuracy: 0.9969 - val_loss: 1.7068 - val_accuracy: 0.7329
#
# Epoch 00017: val_loss did not improve from 1.65356
# Epoch 18/50
# 6680/6680 [==============================] - 2s 240us/step - loss: 0.0103 - accuracy: 0.9973 - val_loss: 1.6755 - val_accuracy: 0.7413
#
# Epoch 00018: val_loss did not improve from 1.65356
# Epoch 19/50
# 6680/6680 [==============================] - 2s 247us/step - loss: 0.0092 - accuracy: 0.9978 - val_loss: 1.7405 - val_accuracy: 0.7317
#
# Epoch 00019: val_loss did not improve from 1.65356
# Epoch 20/50
# 6680/6680 [==============================] - 2s 250us/step - loss: 0.0170 - accuracy: 0.9966 - val_loss: 1.7113 - val_accuracy: 0.7353
#
# Epoch 00020: val_loss did not improve from 1.65356
# Epoch 21/50
# 6680/6680 [==============================] - 2s 247us/step - loss: 0.0125 - accuracy: 0.9964 - val_loss: 1.7109 - val_accuracy: 0.7305
#
# Epoch 00021: val_loss did not improve from 1.65356
# Epoch 22/50
# 6680/6680 [==============================] - 2s 246us/step - loss: 0.0112 - accuracy: 0.9979 - val_loss: 1.6729 - val_accuracy: 0.7353
#
# Epoch 00022: val_loss did not improve from 1.65356
# Epoch 23/50
# 6680/6680 [==============================] - 2s 245us/step - loss: 0.0106 - accuracy: 0.9978 - val_loss: 1.6829 - val_accuracy: 0.7389
#
# Epoch 00023: val_loss did not improve from 1.65356
# Epoch 24/50
# 6680/6680 [==============================] - 2s 246us/step - loss: 0.0177 - accuracy: 0.9972 - val_loss: 1.7062 - val_accuracy: 0.7353
#
# Epoch 00024: val_loss did not improve from 1.65356
# Epoch 25/50
# 6680/6680 [==============================] - 2s 244us/step - loss: 0.0118 - accuracy: 0.9973 - val_loss: 1.8186 - val_accuracy: 0.7365
#
# Epoch 00025: val_loss did not improve from 1.65356
# Epoch 26/50
# 6680/6680 [==============================] - 2s 238us/step - loss: 0.0121 - accuracy: 0.9976 - val_loss: 1.7105 - val_accuracy: 0.7413
#
# Epoch 00026: val_loss did not improve from 1.65356
# Epoch 27/50
# 6680/6680 [==============================] - 2s 246us/step - loss: 0.0103 - accuracy: 0.9976 - val_loss: 1.6702 - val_accuracy: 0.7401
#
# Epoch 00027: val_loss did not improve from 1.65356
# Epoch 28/50
# 6680/6680 [==============================] - 2s 242us/step - loss: 0.0108 - accuracy: 0.9979 - val_loss: 1.7023 - val_accuracy: 0.7413
#
# Epoch 00028: val_loss did not improve from 1.65356
# Epoch 29/50
# 6680/6680 [==============================] - 2s 250us/step - loss: 0.0099 - accuracy: 0.9981 - val_loss: 1.7751 - val_accuracy: 0.7365
#
# Epoch 00029: val_loss did not improve from 1.65356
# Epoch 30/50
# 6680/6680 [==============================] - 2s 240us/step - loss: 0.0088 - accuracy: 0.9976 - val_loss: 1.8132 - val_accuracy: 0.7377
#
# Epoch 00030: val_loss did not improve from 1.65356
# Epoch 31/50
# 6680/6680 [==============================] - 2s 237us/step - loss: 0.0160 - accuracy: 0.9978 - val_loss: 1.6968 - val_accuracy: 0.7401
#
# Epoch 00031: val_loss did not improve from 1.65356
# Epoch 32/50
# 6680/6680 [==============================] - 2s 239us/step - loss: 0.0116 - accuracy: 0.9978 - val_loss: 1.7446 - val_accuracy: 0.7317
#
# Epoch 00032: val_loss did not improve from 1.65356
# Epoch 33/50
# 6680/6680 [==============================] - 2s 242us/step - loss: 0.0112 - accuracy: 0.9978 - val_loss: 1.6796 - val_accuracy: 0.7425
#
# Epoch 00033: val_loss did not improve from 1.65356
# Epoch 34/50
# 6680/6680 [==============================] - 2s 243us/step - loss: 0.0086 - accuracy: 0.9981 - val_loss: 1.7099 - val_accuracy: 0.7365
#
# Epoch 00034: val_loss did not improve from 1.65356
# Epoch 35/50
# 6680/6680 [==============================] - 2s 241us/step - loss: 0.0057 - accuracy: 0.9990 - val_loss: 1.6766 - val_accuracy: 0.7425
#
# Epoch 00035: val_loss did not improve from 1.65356
# Epoch 36/50
# 6680/6680 [==============================] - 2s 240us/step - loss: 0.0120 - accuracy: 0.9979 - val_loss: 1.7264 - val_accuracy: 0.7329
#
# Epoch 00036: val_loss did not improve from 1.65356
# Epoch 37/50
# 6680/6680 [==============================] - 2s 242us/step - loss: 0.0098 - accuracy: 0.9976 - val_loss: 1.6951 - val_accuracy: 0.7389
#
# Epoch 00037: val_loss did not improve from 1.65356
# Epoch 38/50
# 6680/6680 [==============================] - 2s 245us/step - loss: 0.0088 - accuracy: 0.9978 - val_loss: 1.6750 - val_accuracy: 0.7425
#
# Epoch 00038: val_loss did not improve from 1.65356
# Epoch 39/50
# 6680/6680 [==============================] - 2s 242us/step - loss: 0.0112 - accuracy: 0.9984 - val_loss: 1.6994 - val_accuracy: 0.7449
#
# Epoch 00039: val_loss did not improve from 1.65356
# Epoch 40/50
# 6680/6680 [==============================] - 2s 244us/step - loss: 0.0106 - accuracy: 0.9979 - val_loss: 1.7059 - val_accuracy: 0.7437
#
# Epoch 00040: val_loss did not improve from 1.65356
# Epoch 41/50
# 6680/6680 [==============================] - 2s 250us/step - loss: 0.0065 - accuracy: 0.9990 - val_loss: 1.6708 - val_accuracy: 0.7449
#
# Epoch 00041: val_loss did not improve from 1.65356
# Epoch 42/50
# 6680/6680 [==============================] - 2s 250us/step - loss: 0.0112 - accuracy: 0.9975 - val_loss: 1.7024 - val_accuracy: 0.7401
#
# Epoch 00042: val_loss did not improve from 1.65356
# Epoch 43/50
# 6680/6680 [==============================] - 2s 247us/step - loss: 0.0093 - accuracy: 0.9985 - val_loss: 1.7174 - val_accuracy: 0.7437
#
# Epoch 00043: val_loss did not improve from 1.65356
# Epoch 44/50
# 6680/6680 [==============================] - 2s 246us/step - loss: 0.0139 - accuracy: 0.9981 - val_loss: 1.6819 - val_accuracy: 0.7449
#
# Epoch 00044: val_loss did not improve from 1.65356
# Epoch 45/50
# 6680/6680 [==============================] - 2s 245us/step - loss: 0.0096 - accuracy: 0.9978 - val_loss: 1.8045 - val_accuracy: 0.7389
#
# Epoch 00045: val_loss did not improve from 1.65356
# Epoch 46/50
# 6680/6680 [==============================] - 2s 246us/step - loss: 0.0117 - accuracy: 0.9984 - val_loss: 1.6759 - val_accuracy: 0.7413
#
# Epoch 00046: val_loss did not improve from 1.65356
# Epoch 47/50
# 6680/6680 [==============================] - 2s 243us/step - loss: 0.0123 - accuracy: 0.9982 - val_loss: 1.6967 - val_accuracy: 0.7425
#
# Epoch 00047: val_loss did not improve from 1.65356
# Epoch 48/50
# 6680/6680 [==============================] - 2s 247us/step - loss: 0.0079 - accuracy: 0.9987 - val_loss: 1.6973 - val_accuracy: 0.7377
#
# Epoch 00048: val_loss did not improve from 1.65356
# Epoch 49/50
# 6680/6680 [==============================] - 2s 247us/step - loss: 0.0098 - accuracy: 0.9985 - val_loss: 1.7363 - val_accuracy: 0.7365
#
# Epoch 00049: val_loss did not improve from 1.65356
# Epoch 50/50
# 6680/6680 [==============================] - 2s 246us/step - loss: 0.0118 - accuracy: 0.9985 - val_loss: 1.6960 - val_accuracy: 0.7425
#
# Epoch 00050: val_loss did not improve from 1.65356

# %% [markdown]
# ### 8. Load the Model with the Best Validation Accuracy (Model 2)

# %%
# load the weights that yielded the best validation accuracy
model.load_weights('dogvgg16.weights.best.hdf5')

# %% [markdown]
# ### 9. Calculate Classification Accuracy on Test Set (Model 2)

# %%
# get index of predicted dog breed for each image in test set
vgg16_predictions = [np.argmax(model.predict(np.expand_dims(feature, axis=0))) 
                     for feature in test_vgg16]

# report test accuracy
test_accuracy = 100*np.sum(np.array(vgg16_predictions)==
                           np.argmax(test_targets, axis=1))/len(vgg16_predictions)
print('\nTest accuracy: %.4f%%' % test_accuracy)
# Out:
# Test accuracy: 74.4019%
